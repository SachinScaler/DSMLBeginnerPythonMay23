# %% [markdown]
# <a href="https://colab.research.google.com/github/SachinScaler/DSMLBeginnerPythonMay23/blob/main/Beginner_Intro_to_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello New Batch")
# Out:
# Hello New Batch

# %%
print('My Name is Sachin')
# Out:
# My Name is Sachin

# %%
# SHIFT + ENTER TO RUN CODE

# %%
print("Hello") # text: Comment
# Out:
# Hello

# %%
print('Hello') # text
# Out:
# Hello

# %%
print(Sachin) # missing quotes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-963262380b8e> in <cell line: 1>()
# ----> 1 print(Sachin)
#
# NameError: name 'Sachin' is not defined

# %% [markdown]
# - TEXT SHOULD BE ENCLOSED IN "<>" or '<>'

# %%
print(9)
# Out:
# 9

# %%
print(9, "Sachin")
# Out:
# 9 Sachin

# %%
print("9") # numbers as text
# Out:
# 9

# %%
print("Hello " + "World") # added two strings: Concatenation
# Out:
# Hello World

# %%
print(1+9) # Add them
# Out:
# 10

# %%
print("10")
# Out:
# 10

# %%
print(20+30)
# Out:
# 50

# %%
print(8-5)
# Out:
# 3

# %%
print(4*9)
# Out:
# 36

# %%
print("5+10") # python is Case-Sensitive
# Out:
# 5+10

# %%
print("5" + "10") # concatenation
# - A: 15
# - B: 510
# - C: Error
# - D: "5 + 10"
# Out:
# 510

# %%
print("5" + '10') # concatenation
# Out:
# 510

# %%
print(5 + '10') # Error: You Can't add two different types
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-3c2e8105785c> in <cell line: 1>()
# ----> 1 print(5 + '10') # Error: You Can't add two different types
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(5 , '10'+ "World", 3*15)
# Out:
# 5 10World 45

# %% [markdown]
# Homework:
# try to perform ( + , -, / , *) on strings, numbers and combinations
# - number, number
# - string , string
# - number, string

# %%
# *
print(12*5)
# Out:
# 60

# %%
print("A"*"B")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-958bdc962dea> in <cell line: 1>()
# ----> 1 print("A"*"B")
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
print("A"*10)
# Out:
# AAAAAAAAAA

# %%
print(10*"A")
# Out:
# AAAAAAAAAA

# %% [markdown]
# - Compiled Languages: Java, C++
# - Interpreted Langauge: Python, JavaScript
#
# IDE's
# - PyCharm
# - VSCODE(This is my favourite)
# - Jupyter Notebook / JupyterLab (It looks exactly same as colab. Advantage: No Need to Connect to internet)

# %%
print(5)

# FIVE
# Out:
# 5

# %%
dict1 = {1:"One", 2:"Two", 3:"Three"}
print(dict1[2])
# Out:
# Two

# %%
print(dict1[3])
# Out:
# Three

# %%
print(dict1[5])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-d24060b05233> in <cell line: 1>()
# ----> 1 print(dict1[5])
#
# KeyError: 5

# %%
print("45")
# Out:
# 45

# %%
print(4 , end = "")
print(5)
# Out:
# 45

# %%
# Out:
# 4  5

# %%
# !python firstPythonScript.py
# Out:
# 15
# hello World

# %%
print(5+10)
# Out:
# 15

# %% [markdown]
# ![Screenshot 2023-05-08 at 6.16.00 PM.png](data:image/png;base64,...)

# %%
print("hello World")
# Out:
# hello World
